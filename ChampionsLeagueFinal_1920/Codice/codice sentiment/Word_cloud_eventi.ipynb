# %%
import pandas as pd
match_int=pd.read_csv('C:/Users/preinstalled/Downloads/match_int.csv')
# Out:
# C:\Users\preinstalled\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (0,2,10,11,12,13,14,15,16,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#seleziono i tweet in ligua italiana
datiITA=match_int.loc[match_int['language'] == 'it']
datiITA
# Out:
#          index Unnamed: 0                       _id coordinates    eventi  \
# 58          81         81  5f42bcf3b957f1aa3f1b64d2         NaN  pressing
# 160        186        186  5f42bcf5b957f1aa3f1b653b         NaN  pressing
# 305        336        336  5f42bcf8b957f1aa3f1b65d1         NaN  pressing
# 381        342        342  5f42bcf8b957f1aa3f1b65d4         NaN  pressing
# 525        494        494  5f42bcfbb957f1aa3f1b666e         NaN  pressing
# ...        ...        ...                       ...         ...       ...
# 310360  262398     257004  5f42d768b957f1aa3f200ba0         NaN       NaN
# 310361  262417     257023  5f42d768b957f1aa3f200bb3         NaN       NaN
# 310488  262587     257193  5f42d76bb957f1aa3f200c5d         NaN       NaN
# 310502  262558     257164  5f42d76bb957f1aa3f200c40         NaN       NaN
# 310541  262622     257228  5f42d76cb957f1aa3f200c80         NaN       NaN
#
#         geo                                    hashtags                   id  \
# ...

# %%
#lista di stop words
import nltk
from nltk.corpus import stopwords
stop = stopwords.words('italian')
stop.extend(['#UCL','#ChampionsLeague','#PSGBayern','#UCLFinal','#PSGFCB'])
stop
# Out:
# ['ad',
#  'al',
#  'allo',
#  'ai',
#  'agli',
#  'all',
#  'agl',
#  'alla',
#  'alle',
#  'con',
#  'col',
#  'coi',
#  'da',
#  'dal',
#  'dallo',
#  'dai',
#  'dagli',
#  'dall',
#  'dagl',
#  'dalla',
#  'dalle',
#  'di',
#  'del',
#  'dello',
#  'dei',
#  'degli',
#  'dell',
#  'degl',
#  'della',
#  'delle',
#  'in',
#  'nel',
#  'nello',
#  'nei',
#  'negli',
#  'nell',
#  'negl',
#  'nella',
#  'nelle',
#  'su',
#  'sul',
#  'sullo',
#  'sui',
#  'sugli',
#  'sull',
#  'sugl',
#  'sulla',
#  'sulle',
#  'per',
#  'tra',
#  'contro',
#  'io',
#  'tu',
#  'lui',
#  'lei',
#  'noi',
#  'voi',
#  'loro',
#  'mio',
#  'mia',
#  'miei',
#  'mie',
#  'tuo',
#  'tua',
#  'tuoi',
#  'tue',
#  'suo',
#  'sua',
#  'suoi',
#  'sue',
#  'nostro',
#  'nostra',
#  'nostri',
#  'nostre',
#  'vostro',
#  'vostra',
#  'vostri',
#  'vostre',
#  'mi',
#  'ti',
#  'ci',
#  'vi',
#  'lo',
#  'la',
#  'li',
#  'le',
#  'gli',
#  'ne',
#  'il',
#  'un',
#  'uno',
#  'una',
#  'ma',
#  'ed',
# ...

# %%
#creo una colonna di liste e rimuovo le stop words
datiITA["text"] =datiITA["text"].str.lower().str.split()
datiITA['text']=datiITA["text"].apply(lambda x: [item for item in x if item not in stop])
# Out:
# C:\Users\preinstalled\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\preinstalled\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
datiITA.head()
# Out:
#      index Unnamed: 0                       _id coordinates    eventi  geo  \
# 58      81         81  5f42bcf3b957f1aa3f1b64d2         NaN  pressing  NaN
# 160    186        186  5f42bcf5b957f1aa3f1b653b         NaN  pressing  NaN
# 305    336        336  5f42bcf8b957f1aa3f1b65d1         NaN  pressing  NaN
# 381    342        342  5f42bcf8b957f1aa3f1b65d4         NaN  pressing  NaN
# 525    494        494  5f42bcfbb957f1aa3f1b666e         NaN  pressing  NaN
#
#                                      hashtags                   id  \
# 58                                         []  1297609810226171905
# 160  ['Champions', 'Psg', 'UCL', 'Champions']  1297609818828681217
# 305                                        []  1297609831562567683
# 381                ['MiaSanMia', 'PSGBayern']  1297609831885541377
# 525                              ['UCLfinal']  1297609844866899969
#
#     is_a_retweet language  ... retweeted soggetti squadre  \
# ...

# %%
#slicing per dataset primo cloudword
daticw1=datiITA.loc[datiITA['timestamp'] >= '2020-08-23 21:22:00']
daticw1=daticw1.loc[daticw1['timestamp'] <= '2020-08-23 21:33:00']
daticw1
# Out:
#        index Unnamed: 0                       _id coordinates      eventi  \
# 49890  49859      49859  5f42c1ddb957f1aa3f1c2743         NaN  palo, tiro
# 49896  49865      49865  5f42c1ddb957f1aa3f1c274a         NaN  palo, tiro
# 49911  49885      49885  5f42c1ddb957f1aa3f1c275e         NaN  palo, tiro
# 50130  50154      50154  5f42c1e2b957f1aa3f1c286b         NaN  palo, tiro
# 50223  50185      50185  5f42c1e3b957f1aa3f1c288a         NaN  palo, tiro
# ...      ...        ...                       ...         ...         ...
# 79543  79514      79514  5f42c463b957f1aa3f1c9b1b         NaN         NaN
# 79573  79591      79591  5f42c464b957f1aa3f1c9b68         NaN         NaN
# 79607  79582      79582  5f42c464b957f1aa3f1c9b5f         NaN         NaN
# 79889  79861      79861  5f42c46ab957f1aa3f1c9c76         NaN         NaN
# 79918  79942      79942  5f42c46bb957f1aa3f1c9cc7         NaN         NaN
#
#        geo                           hashtags                   id  \
# ...

# %%
#slicing dataset secondo cloudword
daticw2=datiITA.loc[datiITA['timestamp'] >= '2020-08-23 21:46:00']
daticw2=daticw2.loc[daticw2['timestamp'] <= '2020-08-23 21:57:00']
daticw2
# Out:
#          index Unnamed: 0                       _id coordinates  \
# 114899  114871     109478  5f42c77db957f1aa3f1d1027         NaN
# 114954  114928     109535  5f42c77eb957f1aa3f1d1060         NaN
# 115046  115023     109630  5f42c780b957f1aa3f1d10bf         NaN
# 115108  115075     109682  5f42c781b957f1aa3f1d10f2         NaN
# 115136  115164     109771  5f42c783b957f1aa3f1d114c         NaN
# ...        ...        ...                       ...         ...
# 146942   26068      26068  5f42c9ffb957f1aa3f1d8d80         NaN
# 147389   26504      26504  5f42ca07b957f1aa3f1d8f34         NaN
# 147442   26524      26524  5f42ca08b957f1aa3f1d8f47         NaN
# 147739   26863      26863  5f42ca0fb957f1aa3f1d909b         NaN
# 147903   26991      26991  5f42ca11b957f1aa3f1d911b         NaN
#
#                                        eventi  geo  \
# 114899  ['contrasto', 'tiro, assist, parata']  NaN
# 114954  ['contrasto', 'tiro, assist, parata']  NaN
# ...

# %%
#slicing dataset terzo cloudword
daticw3=datiITA.loc[datiITA['timestamp'] >= '2020-08-23 22:17:00']
daticw3=daticw3.loc[daticw3['timestamp'] <= '2020-08-23 22:28:00']
daticw3
# Out:
#          index Unnamed: 0                       _id coordinates  \
# 200680  152730     147337  5f42cec1b957f1aa3f1e5f3b         NaN
# 200722  152826     147433  5f42cec2b957f1aa3f1e5f9b         NaN
# 200731  152807     147414  5f42cec2b957f1aa3f1e5f88         NaN
# 200992  153043     147650  5f42cec7b957f1aa3f1e6073         NaN
# 201081  153185     147792  5f42cec9b957f1aa3f1e6102         NaN
# ...        ...        ...                       ...         ...
# 233542  185590     180197  5f42d152b957f1aa3f1edf97         NaN
# 233572  185631     180238  5f42d153b957f1aa3f1edfbf         NaN
# 233583  185644     180251  5f42d153b957f1aa3f1edfcd         NaN
# 233596  185708     180315  5f42d155b957f1aa3f1ee00d         NaN
# 233617  185673     180280  5f42d154b957f1aa3f1edfea         NaN
#
#                eventi  geo                       hashtags  \
# 200680   [nan, 'gol']  NaN                  ['PSGBayern']
# 200722   [nan, 'gol']  NaN                  ['PSGBayern']
# ...

# %%
daticw1.to_csv('cw1.csv',sep=';')
daticw2.to_csv('cw2.csv',sep=';')
daticw3.to_csv('cw3.csv',sep=';')
